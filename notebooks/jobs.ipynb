# %%
import json
from pathlib import Path

from peterbot.data_json.jobs_json import max_job_id, save_job
from peterbot.jobs import test_job

data_path = Path('..') / 'data'
jobs_path = data_path / 'jobs.json'
# print(f"{data_path} exists? {data_path.exists()}")
print(f"{jobs_path} exists? {jobs_path.exists()}")

# %% [markdown]
# # Read Jobs

# %% [markdown]
# # Edit Jobs

# %% [markdown]
# ### Add new job

# %%
job = {"job_id": max_job_id(jobs_path)+1}
save_job(job, jobs_path)

# %% [markdown]
# # Run test job

# %%
test_job.run(data_path)
