# %%
from pathlib import Path


data_path = Path('..') / 'data'
jobs_path = data_path / 'jobs.json'
print(f"{jobs_path} exists? {jobs_path.exists()}")

# %% [markdown]
# # Read Jobs

# %% [markdown]
# # Edit Jobs

# %% [markdown]
# ### Add new job to json db

# %%
from peterbot.data.jobs_db_json import max_job_id, save_job

job = {"job_id": max_job_id(jobs_path)+1}
save_job(job, jobs_path)

# %% [markdown]
# # Run Jobs

# %%
from peterbot.jobs import test_job
test_job.run(data_path)

# %%
from peterbot.jobs import update_diocese_parishes
update_diocese_parishes.run(data_path, 1)
